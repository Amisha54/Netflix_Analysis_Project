# %% [markdown]
# Netflix dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv(r"E:\netflix_movies_and_tv_shows_sample_dataset_sample.csv")

# %%
data
# Out:
#                                         URL
# 0    https://www.netflix.com/title/80189221  \
# 1    https://www.netflix.com/title/81031373
# 2    https://www.netflix.com/title/80996601
# 3    https://www.netflix.com/title/81350429
# 4    https://www.netflix.com/title/81149184
# ..                                      ...
# 143  https://www.netflix.com/title/81021929
# 144  https://www.netflix.com/title/81123055
# 145  https://www.netflix.com/title/81036622
# 146  https://www.netflix.com/title/81464765
# 147  https://www.netflix.com/title/81435684
#
#                                                  Name ContentType
# 0                          The Haunting of Hill House    TVSeries  \
# 1    Don't F**k with Cats: Hunting an Internet Killer    TVSeries
# 2                                       Love Is Blind    TVSeries
# 3                                        I Care a Lot       Movie
# 4                                  tick, tick...BOOM!       Movie
# ...

# %%
data.head()
# Out:
#                                       URL
# 0  https://www.netflix.com/title/80189221  \
# 1  https://www.netflix.com/title/81031373
# 2  https://www.netflix.com/title/80996601
# 3  https://www.netflix.com/title/81350429
# 4  https://www.netflix.com/title/81149184
#
#                                                Name ContentType
# 0                        The Haunting of Hill House    TVSeries  \
# 1  Don't F**k with Cats: Hunting an Internet Killer    TVSeries
# 2                                     Love Is Blind    TVSeries
# 3                                      I Care a Lot       Movie
# 4                                tick, tick...BOOM!       Movie
#
#                                          Description ContentRating
# 0  Flashing between past and present, a fractured...           18+  \
# 1  A twisted criminal's gruesome videos drive a g...           18+
# 2  Nick and Vanessa Lachey host this social exper...           16+
# ...

# %%
data.tail()
# Out:
#                                         URL                             Name
# 143  https://www.netflix.com/title/81021929                      Space Force  \
# 144  https://www.netflix.com/title/81123055                 In From the Cold
# 145  https://www.netflix.com/title/81036622                          Toy Boy
# 146  https://www.netflix.com/title/81464765  14 Peaks: Nothing Is Impossible
# 147  https://www.netflix.com/title/81435684                           Arcane
#
#     ContentType                                        Description
# 143    TVSeries  A four-star general begrudgingly teams up with...  \
# 144    TVSeries  Exposed as an ex-Russian spy, an American sing...
# 145    TVSeries  After seven years in a Málaga prison, a male s...
# 146       Movie  Fearless Nepali mountaineer Nimsdai Purja emba...
# 147    TVSeries  Amid the stark discord of twin cities Piltover...
#
#     ContentRating             Genre
# 143           16+       TV Comedies  \
# ...

# %%
data.shape
# Out:
# (148, 21)

# %%
data.size
# Out:
# 3108

# %%
data.columns
# Out:
# Index(['URL', 'Name', 'ContentType', 'Description', 'ContentRating', 'Genre',
#        'Poster', 'FormattedDuration', 'ReleasedDate', 'Actors', 'Director',
#        'Creator', 'Audio', 'Subtitle', 'AvailableForOffline',
#        'NumberOfSeasons', 'SeasonStartDate', 'Source', 'SourceLink', 'Uniq-Id',
#        'ScrapedAt'],
#       dtype='object')

# %%
data.dtypes
# Out:
# URL                     object
# Name                    object
# ContentType             object
# Description             object
# ContentRating           object
# Genre                   object
# Poster                  object
# FormattedDuration       object
# ReleasedDate            object
# Actors                  object
# Director                object
# Creator                 object
# Audio                   object
# Subtitle                object
# AvailableForOffline     object
# NumberOfSeasons        float64
# SeasonStartDate         object
# Source                  object
# SourceLink              object
# Uniq-Id                 object
# ScrapedAt               object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   URL                  148 non-null    object
#  1   Name                 148 non-null    object
#  2   ContentType          148 non-null    object
#  3   Description          148 non-null    object
#  4   ContentRating        148 non-null    object
#  5   Genre                148 non-null    object
#  6   Poster               148 non-null    object
#  7   FormattedDuration    43 non-null     object
#  8   ReleasedDate         148 non-null    object
#  9   Actors               132 non-null    object
#  10  Director             51 non-null     object
#  11  Creator              74 non-null     object
#  12  Audio                43 non-null     object
#  13  Subtitle             43 non-null     object
#  14  AvailableForOffline  148 non-null    object
# ...

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [URL, Name, ContentType, Description, ContentRating, Genre, Poster, FormattedDuration, ReleasedDate, Actors, Director, Creator, Audio, Subtitle, AvailableForOffline, NumberOfSeasons, SeasonStartDate, Source, SourceLink, Uniq-Id, ScrapedAt]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# no any duplicated value present in my project

# %%
data.head()
# Out:
#                                       URL
# 0  https://www.netflix.com/title/80189221  \
# 1  https://www.netflix.com/title/81031373
# 2  https://www.netflix.com/title/80996601
# 3  https://www.netflix.com/title/81350429
# 4  https://www.netflix.com/title/81149184
#
#                                                Name ContentType
# 0                        The Haunting of Hill House    TVSeries  \
# 1  Don't F**k with Cats: Hunting an Internet Killer    TVSeries
# 2                                     Love Is Blind    TVSeries
# 3                                      I Care a Lot       Movie
# 4                                tick, tick...BOOM!       Movie
#
#                                          Description ContentRating
# 0  Flashing between past and present, a fractured...           18+  \
# 1  A twisted criminal's gruesome videos drive a g...           18+
# 2  Nick and Vanessa Lachey host this social exper...           16+
# ...

# %%
data.isnull()
# Out:
#        URL   Name  ContentType  Description  ContentRating  Genre  Poster
# 0    False  False        False        False          False  False   False  \
# 1    False  False        False        False          False  False   False
# 2    False  False        False        False          False  False   False
# 3    False  False        False        False          False  False   False
# 4    False  False        False        False          False  False   False
# ..     ...    ...          ...          ...            ...    ...     ...
# 143  False  False        False        False          False  False   False
# 144  False  False        False        False          False  False   False
# 145  False  False        False        False          False  False   False
# 146  False  False        False        False          False  False   False
# 147  False  False        False        False          False  False   False
#
#      FormattedDuration  ReleasedDate  Actors  ...  Creator  Audio  Subtitle
# ...

# %%
data.isnull().sum()
# Out:
# URL                      0
# Name                     0
# ContentType              0
# Description              0
# ContentRating            0
# Genre                    0
# Poster                   0
# FormattedDuration      105
# ReleasedDate             0
# Actors                  16
# Director                97
# Creator                 74
# Audio                  105
# Subtitle               105
# AvailableForOffline      0
# NumberOfSeasons         43
# SeasonStartDate         43
# Source                   0
# SourceLink               0
# Uniq-Id                  0
# ScrapedAt                0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# To show all the record of a particulrar item in any column.

# %%
data[data['Name'].isin(['Love, Death & Robots'])]
# Out:
#                                         URL                  Name ContentType
# 130  https://www.netflix.com/title/80174608  Love, Death & Robots    TVSeries  \
#
#                                            Description ContentRating
# 130  Terrifying creatures, wicked surprises and dar...           18+  \
#
#                  Genre                                             Poster
# 130  Horror TV Serials  https://occ-0-1492-1007.1.nflxso.net/dnm/api/v...  \
#
#     FormattedDuration ReleasedDate
# 130               NaN     15-03-19  \
#
#                                                 Actors  ...
# 130  Michael B. Jordan, Elodie Yung, Joe Dempsie, T...  ...  \
#
#                                                Creator Audio Subtitle
# 130  Tim Miller, David Fincher, Jennifer Miller, Jo...   NaN      NaN  \
#
#        AvailableForOffline NumberOfSeasons  SeasonStartDate   Source
# 130  Available to download             2.0         15-03-19  Netflix  \
#
# ...

# %% [markdown]
# In which year highest number of TV Shows and Movies were Released? Show with  bar graph.

# %%
data['Date'] = pd.to_datetime(data['ReleasedDate'])
data.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5608\884045596.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date'] = pd.to_datetime(data['ReleasedDate'])
#                                       URL
# 0  https://www.netflix.com/title/80189221  \
# 1  https://www.netflix.com/title/81031373
# 2  https://www.netflix.com/title/80996601
# 3  https://www.netflix.com/title/81350429
# 4  https://www.netflix.com/title/81149184
#
#                                                Name ContentType
# 0                        The Haunting of Hill House    TVSeries  \
# 1  Don't F**k with Cats: Hunting an Internet Killer    TVSeries
# 2                                     Love Is Blind    TVSeries
# 3                                      I Care a Lot       Movie
# 4                                tick, tick...BOOM!       Movie
#
# ...

# %%
data['Date'].dt.year.value_counts()
# Out:
# Date
# 2021    46
# 2022    32
# 2019    22
# 2020    19
# 2018    14
# 2016     8
# 2017     6
# 2015     1
# Name: count, dtype: int64

# %%
data['Date'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# How many movies and shows are in the dataset? Show the percentage and  Top 10 Popular Geners on Netflix

# %%
data['ContentType'].value_counts()
# Out:
# ContentType
# TVSeries    105
# Movie        43
# Name: count, dtype: int64

# %%
sns.countplot(data=data,x='ContentType')
fig = plt.gcf()
fig.set_size_inches(7, 5)
plt.title('Netflix')
plt.xlabel("Netflix (TVSeries/Movie)")
plt.ylabel("Total Count")
plt.show()

# %%
total_count = len(data)
content_type_counts = data['ContentType'].value_counts()
percentage = (content_type_counts / total_count) * 100

plt.pie(percentage, explode=(0.025, 0.025), labels=percentage.index, colors=['yellow', 'orange'],
        autopct='%1.1f%%', startangle=180)
plt.title('Percentage of Netflix Content Types')
plt.show()

# %%
sns.countplot(data=data, y='Genre', order=data['Genre'].value_counts().head(10).index)
plt.title('Top 10 Genres on Netflix')
plt.show()

# %% [markdown]
# Show all the TV Shows and Movies that were released in 2022

# %%
data['Year'] = data['Date'].dt.year
data.head()
# Out:
#                                       URL
# 0  https://www.netflix.com/title/80189221  \
# 1  https://www.netflix.com/title/81031373
# 2  https://www.netflix.com/title/80996601
# 3  https://www.netflix.com/title/81350429
# 4  https://www.netflix.com/title/81149184
#
#                                                Name ContentType
# 0                        The Haunting of Hill House    TVSeries  \
# 1  Don't F**k with Cats: Hunting an Internet Killer    TVSeries
# 2                                     Love Is Blind    TVSeries
# 3                                      I Care a Lot       Movie
# 4                                tick, tick...BOOM!       Movie
#
#                                          Description ContentRating
# 0  Flashing between past and present, a fractured...           18+  \
# 1  A twisted criminal's gruesome videos drive a g...           18+
# 2  Nick and Vanessa Lachey host this social exper...           16+
# ...

# %%
data[(data['ContentType'] == 'Movie') & (data['Year'] == 2022)]
data.head()
# Out:
#                                       URL
# 0  https://www.netflix.com/title/80189221  \
# 1  https://www.netflix.com/title/81031373
# 2  https://www.netflix.com/title/80996601
# 3  https://www.netflix.com/title/81350429
# 4  https://www.netflix.com/title/81149184
#
#                                                Name ContentType
# 0                        The Haunting of Hill House    TVSeries  \
# 1  Don't F**k with Cats: Hunting an Internet Killer    TVSeries
# 2                                     Love Is Blind    TVSeries
# 3                                      I Care a Lot       Movie
# 4                                tick, tick...BOOM!       Movie
#
#                                          Description ContentRating
# 0  Flashing between past and present, a fractured...           18+  \
# 1  A twisted criminal's gruesome videos drive a g...           18+
# 2  Nick and Vanessa Lachey host this social exper...           16+
# ...

# %% [markdown]
# Show top 7 directors who gave highest number of TV Shows and Movies to Netflix

# %%
data['Director'].value_counts()
data.head(7)
# Out:
#                                       URL
# 0  https://www.netflix.com/title/80189221  \
# 1  https://www.netflix.com/title/81031373
# 2  https://www.netflix.com/title/80996601
# 3  https://www.netflix.com/title/81350429
# 4  https://www.netflix.com/title/81149184
# 5  https://www.netflix.com/title/81083626
# 6  https://www.netflix.com/title/80180171
#
#                                                Name ContentType
# 0                        The Haunting of Hill House    TVSeries  \
# 1  Don't F**k with Cats: Hunting an Internet Killer    TVSeries
# 2                                     Love Is Blind    TVSeries
# 3                                      I Care a Lot       Movie
# 4                                tick, tick...BOOM!       Movie
# 5                                     Midnight Mass    TVSeries
# 6                                           Kingdom    TVSeries
#
#                                          Description ContentRating
# ...

# %% [markdown]
# Different Rating define and how many TV Shows / Movies - 18+ Rating in Natflix

# %%
data['ContentRating'].unique()
# Out:
# array(['18+', '16+', '13+', '7+', 'All'], dtype=object)

# %%
sns.countplot(data=data, x='ContentRating')
fig = plt.gcf()
fig.set_size_inches(10, 5)
plt.title("ContentRating for TVSeries & Movie")
plt.xlabel("ContentRating")
plt.ylabel("Total Count")
plt.legend(title='Type', loc='upper right')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
#  Find all the instances where: Category is 'Movie' and Type is 'Dramas'

# %%
data[(data['ContentType'] == 'TVSeries') & (data ['Genre'] == 'TVDramas')]
data.head(5)
# Out:
#                                       URL
# 0  https://www.netflix.com/title/80189221  \
# 1  https://www.netflix.com/title/81031373
# 2  https://www.netflix.com/title/80996601
# 3  https://www.netflix.com/title/81350429
# 4  https://www.netflix.com/title/81149184
#
#                                                Name ContentType
# 0                        The Haunting of Hill House    TVSeries  \
# 1  Don't F**k with Cats: Hunting an Internet Killer    TVSeries
# 2                                     Love Is Blind    TVSeries
# 3                                      I Care a Lot       Movie
# 4                                tick, tick...BOOM!       Movie
#
#                                          Description ContentRating
# 0  Flashing between past and present, a fractured...           18+  \
# 1  A twisted criminal's gruesome videos drive a g...           18+
# 2  Nick and Vanessa Lachey host this social exper...           16+
# ...
